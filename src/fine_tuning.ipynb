# %% [markdown]
# ### Installation

# %%
# %%capture
import os, re
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    import torch; v = re.match(r"[0-9\.]{3,}", str(torch.__version__)).group(0)
    xformers = "xformers==" + ("0.0.32.post2" if v == "2.8.0" else "0.0.29.post3")
    # !pip install --no-deps bitsandbytes accelerate {xformers} peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    "unsloth/Qwen3-14B-unsloth-bnb-4bit"
]

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-14B",
    max_seq_length = 2048,   # Context length - can be longer, but uses more memory
    load_in_4bit = True,     # 4bit uses much less memory
    load_in_8bit = False,    # A bit more accurate, uses 2x memory
    full_finetuning = False, 
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.8.9: Fast Qwen3 patching. Transformers: 4.55.2.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.59G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/1.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32,           # Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,  # Best to choose alpha = rank or rank*2
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2025.8.9 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep

# %% [markdown]
# We have to use Unsloth's `standardize_sharegpt` function to fix up the format of the dataset first.

# %%
from datasets import load_dataset, Dataset
dataset = load_dataset(
    "json",
    data_files={"train": "./data/processed/ft/srd_chat_augmented.jsonl"},
    split="train",
    encoding="utf-8"
)

from unsloth.chat_templates import standardize_sharegpt
dataset = standardize_sharegpt(dataset)
reasoning_data = tokenizer.apply_chat_template(
    dataset["messages"],
    tokenize = False
)

# %%
reasoning_data[0]
# Out:
# '<|im_start|>user\nWhat information can be found in the racial traits section of a race\'s description in Dungeons & Dragons?<|im_end|>\n<|im_start|>assistant\n<think>\n Okay, so I need to explain the description of each race in Dungeons and Dragons, focusing on the racial traits that are common to members of that race. The key point is that the description includes entries that appear among the traits of most races. Let me think about how to approach this. In D&D, each race has a set of traits that define its abilities, characteristics, and limitations. These traits are standardized across all races and typically include things like size, speed, ability score increases, and special features like darkvision or resistance to certain damage types. The common entries that appear in most race descriptions would be things like "Size," "Speed," "Ability Score Increases," and "Traits." These are standard because they provide a consistent framework for understanding how each race functions within the game. For example, every race has a base speed, which determines how far they can move in a turn. Similarly, most races have specific ability score increases that reflect their natural strengths or weaknesses. Additionally, many races have traits that are unique to them, such as "Darkvision" or "Damage Resistance," but the structure of the description remains the same. This consistency helps players and Dungeon Masters understand and compare different races easily. So, the answer should highlight that the description of each race includes standard entries like size, speed, ability score increases, and traits, which are common to all races and serve as a template for defining each race\'s characteristics. \n</think>\n\nThe description of each race includes racial traits that are common to members of that race. The following entries appear among the traits of most races.<|im_end|>\n'

# %%
train_dataset = Dataset.from_dict({"text": reasoning_data})

# %%
train_dataset[0]
# Out:
# {'text': '<|im_start|>user\nWhat information can be found in the racial traits section of a race\'s description in Dungeons & Dragons?<|im_end|>\n<|im_start|>assistant\n<think>\n Okay, so I need to explain the description of each race in Dungeons and Dragons, focusing on the racial traits that are common to members of that race. The key point is that the description includes entries that appear among the traits of most races. Let me think about how to approach this. In D&D, each race has a set of traits that define its abilities, characteristics, and limitations. These traits are standardized across all races and typically include things like size, speed, ability score increases, and special features like darkvision or resistance to certain damage types. The common entries that appear in most race descriptions would be things like "Size," "Speed," "Ability Score Increases," and "Traits." These are standard because they provide a consistent framework for understanding how each race functions within the game. For example, every race has a base speed, which determines how far they can move in a turn. Similarly, most races have specific ability score increases that reflect their natural strengths or weaknesses. Additionally, many races have traits that are unique to them, such as "Darkvision" or "Damage Resistance," but the structure of the description remains the same. This consistency helps players and Dungeon Masters understand and compare different races easily. So, the answer should highlight that the description of each race includes standard entries like size, speed, ability score increases, and traits, which are common to all races and serve as a template for defining each race\'s characteristics. \n</think>\n\nThe description of each race includes racial traits that are common to members of that race. The following entries appear among the traits of most races.<|im_end|>\n'}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's train our model. We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTTrainer, SFTConfig
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    eval_dataset = None,
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 30,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none",
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/1779 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.557 GB.
# 13.324 GB of memory reserved.

# %% [markdown]
# Let's train the model! To resume a training run, set `trainer.train(resume_from_checkpoint = True)`

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,779 | Num Epochs = 1 | Total steps = 30
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 128,450,560 of 14,896,757,760 (0.86% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 01:51, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.286100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.324000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.539600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.302200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.120100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.286100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.961100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.007500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.962300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.876200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.076700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.045300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.849900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.804400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.753900</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.754300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.893600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.910600</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.958800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.785900</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.815000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.807700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.838200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.938900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.888000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.853800</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.816500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.778100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.765600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.764200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 124.0897 seconds used for training.
# 2.07 minutes used for training.
# Peak reserved memory = 14.051 GB.
# Peak reserved memory for training = 0.727 GB.
# Peak reserved memory % of max memory = 35.521 %.
# Peak reserved memory for training % of max memory = 1.838 %.

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False:
    model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False:
    model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: # Pushing to HF Hub
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if True: # Pushing to HF Hub
    model.push_to_hub_gguf("astrevallion/Qwen3-14B-FT", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )
# Out:
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 11.1G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 56.14 out of 83.48 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
#  85%|████████▌ | 34/40 [00:00<00:00, 46.13it/s]
# We will save to Disk and not RAM now.
# 100%|██████████| 40/40 [00:07<00:00,  5.40it/s]
# Unsloth: Saving tokenizer... Done.
# Done.
# Unsloth: Converting qwen3 model. Can use fast conversion = False.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp might take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GGUF 16bits might take 3 minutes.
# \        /    [2] Converting GGUF 16bits to ['q4_k_m'] might take 10 minutes each.
#  "-____-"     In total, you will have to wait at least 16 minutes.
#
# Unsloth: Installing llama.cpp. This might take 3 minutes...
# Unsloth: CMAKE detected. Finalizing some steps for installation.
# Unsloth: [1] Converting model at astrevallion/Qwen3-14B-FT into bf16 GGUF format.
# The output location will be /content/astrevallion/Qwen3-14B-FT/unsloth.BF16.gguf
# This might take 3 minutes...
# INFO:hf-to-gguf:Loading model: Qwen3-14B-FT
# INFO:hf-to-gguf:Model architecture: Qwen3ForCausalLM
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00006.safetensors'
# INFO:hf-to-gguf:token_embd.weight,         torch.bfloat16 --> BF16, shape = {5120, 151936}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.0.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.0.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.1.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.1.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.2.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.2.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.3.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.3.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.4.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.4.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.5.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.5.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00006.safetensors'
# INFO:hf-to-gguf:blk.10.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.10.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.10.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.11.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.11.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.12.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.12.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.12.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.6.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.6.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.6.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.7.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.7.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.7.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.8.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.8.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.8.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,     torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,     torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,       torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.9.attn_k_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_k.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.9.attn_output.weight,  torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.9.attn_q_norm.weight,  torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_q.weight,       torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.9.attn_v.weight,       torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00003-of-00006.safetensors'
# INFO:hf-to-gguf:blk.12.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.13.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.13.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.14.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.14.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.15.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.15.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.15.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.16.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.16.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.16.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.17.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.17.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.17.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.17.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.18.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.18.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.18.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.18.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.19.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.19.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.19.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.19.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.19.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.19.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.20.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.20.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.20.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.20.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00004-of-00006.safetensors'
# INFO:hf-to-gguf:blk.20.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.20.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.20.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.21.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.21.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.21.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.21.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.22.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.22.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.22.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.22.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.22.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.22.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.23.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.23.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.23.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.23.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.23.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.23.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.24.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.24.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.24.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.24.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.24.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.24.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.24.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.25.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.25.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.25.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.25.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.25.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.25.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.26.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.26.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.26.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.26.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.26.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.26.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.27.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.27.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.27.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.27.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00005-of-00006.safetensors'
# INFO:hf-to-gguf:blk.27.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.27.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.27.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.28.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.28.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.28.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.28.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.28.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.28.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.28.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.28.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.29.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.29.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.29.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.29.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.29.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.29.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.29.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.29.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.29.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.29.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.29.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.30.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.30.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.30.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.30.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.30.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.30.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.30.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.30.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.30.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.30.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.30.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.31.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.31.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.31.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.31.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.31.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.31.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.31.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.31.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.31.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.31.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.31.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.32.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.32.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.32.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.32.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.32.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.32.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.32.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.32.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.32.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.32.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.32.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.33.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.33.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.33.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.33.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.33.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.33.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.33.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.33.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.33.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.33.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.33.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.34.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.34.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.34.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.34.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.34.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.34.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.34.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.34.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.34.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.35.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.35.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.35.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.35.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00006-of-00006.safetensors'
# INFO:hf-to-gguf:output.weight,             torch.bfloat16 --> BF16, shape = {5120, 151936}
# INFO:hf-to-gguf:blk.35.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.35.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.35.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.35.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.35.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.35.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.35.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.36.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.36.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.36.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.36.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.36.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.36.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.36.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.36.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.37.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.37.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.37.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.37.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.37.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.37.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.37.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.37.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.37.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.37.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.37.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.38.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.38.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.38.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.38.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.38.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.38.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.38.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.38.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.38.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.38.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.38.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.39.attn_norm.weight,   torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.39.ffn_down.weight,    torch.bfloat16 --> BF16, shape = {17408, 5120}
# INFO:hf-to-gguf:blk.39.ffn_gate.weight,    torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.39.ffn_up.weight,      torch.bfloat16 --> BF16, shape = {5120, 17408}
# INFO:hf-to-gguf:blk.39.ffn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.39.attn_k_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.39.attn_k.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.39.attn_output.weight, torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.39.attn_q_norm.weight, torch.bfloat16 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.39.attn_q.weight,      torch.bfloat16 --> BF16, shape = {5120, 5120}
# INFO:hf-to-gguf:blk.39.attn_v.weight,      torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:output_norm.weight,        torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 40960
# INFO:hf-to-gguf:gguf: embedding length = 5120
# INFO:hf-to-gguf:gguf: feed forward length = 17408
# INFO:hf-to-gguf:gguf: head count = 40
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 1000000
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-06
# INFO:hf-to-gguf:gguf: file type = 32
# INFO:hf-to-gguf:Set model quantization version
# INFO:hf-to-gguf:Set model tokenizer
# INFO:numexpr.utils:NumExpr defaulting to 12 threads.
# INFO:gguf.vocab:Adding 151387 merge(s).
# INFO:gguf.vocab:Setting special token type eos to 151645
# INFO:gguf.vocab:Setting special token type pad to 151654
# INFO:gguf.vocab:Setting add_bos_token to False
# INFO:gguf.vocab:Setting chat_template to {%- if tools %}
#     {{- '<|im_start|>system\n' }}
#     {%- if messages[0].role == 'system' %}
#         {{- messages[0].content + '\n\n' }}
#     {%- endif %}
#     {{- "# Tools\n\nYou may call one or more functions to assist with the user query.\n\nYou are provided with function signatures within <tools></tools> XML tags:\n<tools>" }}
#     {%- for tool in tools %}
#         {{- "\n" }}
#         {{- tool | tojson }}
#     {%- endfor %}
#     {{- "\n</tools>\n\nFor each function call, return a json object with function name and arguments within <tool_call></tool_call> XML tags:\n<tool_call>\n{\"name\": <function-name>, \"arguments\": <args-json-object>}\n</tool_call><|im_end|>\n" }}
# {%- else %}
#     {%- if messages[0].role == 'system' %}
#         {{- '<|im_start|>system\n' + messages[0].content + '<|im_end|>\n' }}
#     {%- endif %}
# {%- endif %}
# {%- set ns = namespace(multi_step_tool=true, last_query_index=messages|length - 1) %}
# {%- for forward_message in messages %}
#     {%- set index = (messages|length - 1) - loop.index0 %}
#     {%- set message = messages[index] %}
#     {%- set tool_start = '<tool_response>' %}
#     {%- set tool_start_length = tool_start|length %}
#     {%- set start_of_message = message.content[:tool_start_length] %}
#     {%- set tool_end = '</tool_response>' %}
#     {%- set tool_end_length = tool_end|length %}
#     {%- set start_pos = (message.content|length) - tool_end_length %}
#     {%- if start_pos < 0 %}
#         {%- set start_pos = 0 %}
#     {%- endif %}
#     {%- set end_of_message = message.content[start_pos:] %}
#     {%- if ns.multi_step_tool and message.role == "user" and not(start_of_message == tool_start and end_of_message == tool_end) %}
#         {%- set ns.multi_step_tool = false %}
#         {%- set ns.last_query_index = index %}
#     {%- endif %}
# {%- endfor %}
# {%- for message in messages %}
#     {%- if (message.role == "user") or (message.role == "system" and not loop.first) %}
#         {{- '<|im_start|>' + message.role + '\n' + message.content + '<|im_end|>' + '\n' }}
#     {%- elif message.role == "assistant" %}
#         {%- set content = message.content %}
#         {%- set reasoning_content = '' %}
#         {%- if message.reasoning_content is defined and message.reasoning_content is not none %}
#             {%- set reasoning_content = message.reasoning_content %}
#         {%- else %}
#             {%- if '</think>' in message.content %}
#                 {%- set content = (message.content.split('</think>')|last).lstrip('\n') %}
#                 {%- set reasoning_content = (message.content.split('</think>')|first).rstrip('\n') %}
#                 {%- set reasoning_content = (reasoning_content.split('<think>')|last).lstrip('\n') %}
#             {%- endif %}
#         {%- endif %}
#         {%- if loop.index0 > ns.last_query_index %}
#             {%- if loop.last or (not loop.last and reasoning_content) %}
#                 {{- '<|im_start|>' + message.role + '\n<think>\n' + reasoning_content.strip('\n') + '\n</think>\n\n' + content.lstrip('\n') }}
#             {%- else %}
#                 {{- '<|im_start|>' + message.role + '\n' + content }}
#             {%- endif %}
#         {%- else %}
#             {{- '<|im_start|>' + message.role + '\n' + content }}
#         {%- endif %}
#         {%- if message.tool_calls %}
#             {%- for tool_call in message.tool_calls %}
#                 {%- if (loop.first and content) or (not loop.first) %}
#                     {{- '\n' }}
#                 {%- endif %}
#                 {%- if tool_call.function %}
#                     {%- set tool_call = tool_call.function %}
#                 {%- endif %}
#                 {{- '<tool_call>\n{"name": "' }}
#                 {{- tool_call.name }}
#                 {{- '", "arguments": ' }}
#                 {%- if tool_call.arguments is string %}
#                     {{- tool_call.arguments }}
#                 {%- else %}
#                     {{- tool_call.arguments | tojson }}
#                 {%- endif %}
#                 {{- '}\n</tool_call>' }}
#             {%- endfor %}
#         {%- endif %}
#         {{- '<|im_end|>\n' }}
#     {%- elif message.role == "tool" %}
#         {%- if loop.first or (messages[loop.index0 - 1].role != "tool") %}
#             {{- '<|im_start|>user' }}
#         {%- endif %}
#         {{- '\n<tool_response>\n' }}
#         {{- message.content }}
#         {{- '\n</tool_response>' }}
#         {%- if loop.last or (messages[loop.index0 + 1].role != "tool") %}
#             {{- '<|im_end|>\n' }}
#         {%- endif %}
#     {%- endif %}
# {%- endfor %}
# {%- if add_generation_prompt %}
#     {{- '<|im_start|>assistant\n' }}
#     {%- if enable_thinking is defined and enable_thinking is false %}
#         {{- '<think>\n\n</think>\n\n' }}
#     {%- endif %}
# {%- endif %}
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/content/astrevallion/Qwen3-14B-FT/unsloth.BF16.gguf: n_tensors = 443, total_size = 29.5G
# Writing: 100%|██████████| 29.5G/29.5G [02:24<00:00, 204Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /content/astrevallion/Qwen3-14B-FT/unsloth.BF16.gguf
# Unsloth: Conversion completed! Output location: /content/astrevallion/Qwen3-14B-FT/unsloth.BF16.gguf
# Unsloth: [2] Converting GGUF 16bit into q4_k_m. This might take 20 minutes...
# main: build = 6264 (043fb27d)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0 for x86_64-linux-gnu
# main: quantizing '/content/astrevallion/Qwen3-14B-FT/unsloth.BF16.gguf' to '/content/astrevallion/Qwen3-14B-FT/unsloth.Q4_K_M.gguf' as Q4_K_M using 24 threads
# llama_model_loader: loaded meta data with 30 key-value pairs and 443 tensors from /content/astrevallion/Qwen3-14B-FT/unsloth.BF16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = qwen3
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Qwen3 14B FT
# llama_model_loader: - kv   3:                           general.finetune str              = FT
# llama_model_loader: - kv   4:                           general.basename str              = Qwen3
# llama_model_loader: - kv   5:                       general.quantized_by str              = Unsloth
# llama_model_loader: - kv   6:                         general.size_label str              = 14B
# llama_model_loader: - kv   7:                           general.repo_url str              = https://huggingface.co/unsloth
# llama_model_loader: - kv   8:                               general.tags arr[str,2]       = ["unsloth", "llama.cpp"]
# llama_model_loader: - kv   9:                          qwen3.block_count u32              = 40
# llama_model_loader: - kv  10:                       qwen3.context_length u32              = 40960
# ...
# [ 334/ 443]                 blk.30.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 335/ 443]            blk.30.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 336/ 443]              blk.30.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 337/ 443]            blk.30.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 338/ 443]                 blk.30.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 339/ 443]            blk.30.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 340/ 443]                 blk.30.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 341/ 443]               blk.30.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 342/ 443]               blk.30.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 343/ 443]               blk.30.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 344/ 443]                 blk.30.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 345/ 443]                 blk.31.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 346/ 443]            blk.31.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 347/ 443]              blk.31.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 348/ 443]            blk.31.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 349/ 443]                 blk.31.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 350/ 443]            blk.31.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 351/ 443]                 blk.31.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 352/ 443]               blk.31.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 353/ 443]               blk.31.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 354/ 443]               blk.31.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 355/ 443]                 blk.31.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 356/ 443]                 blk.32.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 357/ 443]            blk.32.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 358/ 443]              blk.32.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 359/ 443]            blk.32.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 360/ 443]                 blk.32.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 361/ 443]            blk.32.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 362/ 443]                 blk.32.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 363/ 443]               blk.32.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 364/ 443]               blk.32.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 365/ 443]               blk.32.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 366/ 443]                 blk.32.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 367/ 443]                 blk.33.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 368/ 443]            blk.33.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 369/ 443]              blk.33.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 370/ 443]            blk.33.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 371/ 443]                 blk.33.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 372/ 443]            blk.33.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 373/ 443]                 blk.33.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 374/ 443]               blk.33.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 375/ 443]               blk.33.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 376/ 443]               blk.33.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 377/ 443]                 blk.33.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 378/ 443]                 blk.34.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 379/ 443]            blk.34.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 380/ 443]              blk.34.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 381/ 443]            blk.34.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 382/ 443]                 blk.34.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 383/ 443]            blk.34.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 384/ 443]                 blk.34.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 385/ 443]               blk.34.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 386/ 443]               blk.34.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 387/ 443]               blk.34.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 388/ 443]                 blk.34.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 389/ 443]                 blk.35.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 390/ 443]            blk.35.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 391/ 443]              blk.35.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 392/ 443]            blk.35.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 393/ 443]                 blk.35.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 394/ 443]            blk.35.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 395/ 443]                 blk.35.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 396/ 443]               blk.35.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 397/ 443]               blk.35.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 398/ 443]               blk.35.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 399/ 443]                 blk.35.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 400/ 443]                 blk.36.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 401/ 443]            blk.36.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 402/ 443]              blk.36.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 403/ 443]            blk.36.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 404/ 443]                 blk.36.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 405/ 443]            blk.36.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 406/ 443]                 blk.36.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 407/ 443]               blk.36.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 408/ 443]               blk.36.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 409/ 443]               blk.36.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 410/ 443]                 blk.36.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 411/ 443]                 blk.37.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 412/ 443]            blk.37.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 413/ 443]              blk.37.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 414/ 443]            blk.37.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 415/ 443]                 blk.37.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 416/ 443]            blk.37.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 417/ 443]                 blk.37.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 418/ 443]               blk.37.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 419/ 443]               blk.37.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 420/ 443]               blk.37.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 421/ 443]                 blk.37.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 422/ 443]                 blk.38.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 423/ 443]            blk.38.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 424/ 443]              blk.38.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 425/ 443]            blk.38.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 426/ 443]                 blk.38.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 427/ 443]            blk.38.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 428/ 443]                 blk.38.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 429/ 443]               blk.38.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 430/ 443]               blk.38.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 431/ 443]               blk.38.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 432/ 443]                 blk.38.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 433/ 443]                 blk.39.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 434/ 443]            blk.39.attn_k_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 435/ 443]              blk.39.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 436/ 443]            blk.39.attn_output.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 437/ 443]                 blk.39.attn_q.weight - [ 5120,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    50.00 MiB ->    14.06 MiB
# [ 438/ 443]            blk.39.attn_q_norm.weight - [  128,     1,     1,     1], type =    f32, size =    0.000 MB
# [ 439/ 443]                 blk.39.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 440/ 443]               blk.39.ffn_down.weight - [17408,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   170.00 MiB ->    69.73 MiB
# [ 441/ 443]               blk.39.ffn_gate.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# [ 442/ 443]               blk.39.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 443/ 443]                 blk.39.ffn_up.weight - [ 5120, 17408,     1,     1], type =   bf16, converting to q4_K .. size =   170.00 MiB ->    47.81 MiB
# llama_model_quantize_impl: model size  = 28169.12 MB
# llama_model_quantize_impl: quant size  =  8579.06 MB
#
# main: quantize time = 250185.76 ms
# main:    total time = 250185.76 ms
# Unsloth: Conversion completed! Output location: /content/astrevallion/Qwen3-14B-FT/unsloth.Q4_K_M.gguf
# Unsloth: Uploading GGUF to Huggingface Hub...
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...on/Qwen3-14B-FT/unsloth.Q4_K_M.gguf:   0%|          |  548kB / 9.00GB
# Saved GGUF to https://huggingface.co/astrevallion/Qwen3-14B-FT
